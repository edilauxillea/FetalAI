# %% [markdown]
# # 1. Download the dataset: Dataset

# %% [markdown]
# # 2. Load the dataset into the tool.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# # 3. Perform Below Visualizations.

# %% [markdown]
# ### Univariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
sns.histplot(df["price"], kde = True)
plt.title("Price")
# Out:
# Text(0.5, 1.0, 'Price')

# %%
plt.boxplot(df["price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23ff71c39d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23ff71c3430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23ff71c3220>],
#  'medians': [<matplotlib.lines.Line2D at 0x23ff70ae250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23ff70ae8e0>],
#  'means': []}

# %%
plt.boxplot(df["area"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23ffaa44910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23ffaa441c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23ff8429610>],
#  'medians': [<matplotlib.lines.Line2D at 0x23ff835f9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23ff835fe80>],
#  'means': []}

# %%
sns.countplot(df["bedrooms"])
plt.title("bedrooms")
# Out:
# C:\Users\angai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'bedrooms')

# %%
x = np.array(df["airconditioning"].unique())
y = np.array(df["airconditioning"].value_counts())
plt.bar(x, y, color=["green", "red"])
plt.title("Air Conditioning")
# Out:
# Text(0.5, 1.0, 'Air Conditioning')

# %%
x = df["parking"].value_counts().to_numpy()
plt.pie(x, labels=np.arange(4))
plt.title("Parking")
# Out:
# Text(0.5, 1.0, 'Parking')

# %% [markdown]
# ### Bi-Variate Analysis

# %%
sns.scatterplot(df["area"], df["price"])
plt.xlabel("Area in sq.ft")
plt.ylabel("Price in crores")
# Out:
# C:\Users\angai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Price in crores')

# %%
df.corr()
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
df.groupby(by='bedrooms').agg('mean')[["price", "area"]]
# Out:
#                  price         area
# bedrooms
# 1         2.712500e+06  3710.000000
# 2         3.632022e+06  4636.235294
# 3         4.954598e+06  5226.620000
# 4         5.729758e+06  5582.063158
# 5         5.819800e+06  6291.500000
# 6         4.791500e+06  3950.000000

# %%
df.groupby(by='furnishingstatus').agg('mean')[["price", "area"]]
# Out:
#                          price         area
# furnishingstatus
# furnished         5.495696e+06  5688.100000
# semi-furnished    4.907524e+06  5166.339207
# unfurnished       4.013831e+06  4707.595506

# %%
sns.kdeplot(data=df, x="area", hue="bedrooms", fill="true")
# Out:
# <AxesSubplot:xlabel='area', ylabel='Density'>

# %%
sns.countplot(data=df, x="bedrooms", hue="parking")
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
sns.boxplot(data=df, x="bedrooms", y="price", palette="rainbow")
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
g = sns.pairplot(df, diag_kind="kde", markers=".",
                 plot_kws=dict(s=50, edgecolor="b", linewidth=1),
                 diag_kws=dict(shade=True))

# %%
crosstab = pd.crosstab(df['bedrooms'], df['parking'])
crosstab
# Out:
# parking     0   1   2  3
# bedrooms
# 1           2   0   0  0
# 2          86  34  15  1
# 3         163  64  66  7
# 4          41  25  25  4
# 5           6   2   2  0
# 6           1   1   0  0

# %%
crosstab = pd.crosstab(df['bedrooms'], df['stories'])
crosstab
# Out:
# stories     1    2   3   4
# bedrooms
# 1           2    0   0   0
# 2         115   20   0   1
# 3         101  143  31  25
# 4           8   65   7  15
# 5           1    8   1   0
# 6           0    2   0   0

# %%
crosstab = pd.crosstab(df['bedrooms'], df['furnishingstatus'])
crosstab
# Out:
# furnishingstatus  furnished  semi-furnished  unfurnished
# bedrooms
# 1                         1               0            1
# 2                        29              50           57
# 3                        76             127           97
# 4                        29              48           18
# 5                         4               2            4
# 6                         1               0            1

# %% [markdown]
# ### Multi-Variate Analysis

# %%
# x2 = x[["price", "area"]]
# x1 = x.drop(["price", "area"], axis=1)
# for i in range(len(x1.columns)):
#     plt.subplot(1,len(x1.columns), i+1)
sns.lmplot("price","area", df, hue="furnishingstatus", fit_reg=True)

# %% [markdown]
# # 4. Perform descriptive statistics on the dataset.

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# # 5. Check for Missing values and deal with them.

# %%
df.isnull().sum()
# There are no null values
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# # 6. Find the outliers and replace them outliers

# %%
sns.boxplot(data=df, y="price")
# Out:
# <AxesSubplot:ylabel='price'>

# %%
sns.boxplot(data=df, y="area")
# Out:
# <AxesSubplot:ylabel='area'>

# %%
Q3 = df["price"].quantile(0.75)
Q1 = df["price"].quantile(0.25)
IQR = Q3 - Q1
IQR
lower_lim = Q1 - 1.5*IQR
upper_lim = Q3 + 1.5*IQR
print(upper_lim,lower_lim)
# Out:
# 9205000.0 -35000.0

# %%
a = np.array(df["price"])
tenth_percentile = np.percentile(a, 5)
ninetieth_percentile = np.percentile(a, 95)
# print(tenth_percentile, ninetieth_percentile)
b = np.where(a<tenth_percentile, tenth_percentile, a)
b = np.where(b>ninetieth_percentile, ninetieth_percentile, b)
df["price"] = b

a = np.array(df["area"])
tenth_percentile = np.percentile(a, 5)
ninetieth_percentile = np.percentile(a, 95)
# print(tenth_percentile, ninetieth_percentile)
b = np.where(a<tenth_percentile, tenth_percentile, a)
b = np.where(b>ninetieth_percentile, ninetieth_percentile, b)
df["area"] = b

# %%
plt.subplot(1,2,1)
sns.boxplot(data=df, y="price")
plt.title("Price")
plt.subplot(1,2,2)
sns.boxplot(data=df, y="area")
plt.title("Area")
# Out:
# Text(0.5, 1.0, 'Area')

# %% [markdown]
# # 7. Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
le = LabelEncoder()
col = df.drop(["price", "area", "bedrooms", "bathrooms", "stories","parking"], axis = 1).columns
df[col] = df[col].apply(le.fit_transform)
df
# Out:
#          price    area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    8400000.0  7420.0         4          2        3         1          0
# 1    8400000.0  8960.0         4          4        4         1          0
# 2    8400000.0  9000.0         3          2        2         1          0
# 3    8400000.0  7500.0         4          2        2         1          0
# 4    8400000.0  7420.0         4          1        2         1          1
# ..         ...     ...       ...        ...      ...       ...        ...
# 540  2450000.0  3000.0         2          1        1         1          0
# 541  2450000.0  2562.0         3          1        1         0          0
# 542  2450000.0  3620.0         2          1        1         1          0
# 543  2450000.0  2910.0         3          1        1         0          0
# 544  2450000.0  3850.0         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %%
sns.pairplot(df, diag_kind="kde", markers=".",
                 plot_kws=dict(s=50, edgecolor="b", linewidth=1),
                 diag_kws=dict(shade=True))

# %% [markdown]
# # 8. Split the data into dependent and independent variables.

# %%
Y = df["price"]
X = df.drop(["price"], axis=1)
X
# Out:
#        area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420.0         4          2        3         1          0         0
# 1    8960.0         4          4        4         1          0         0
# 2    9000.0         3          2        2         1          0         1
# 3    7500.0         4          2        2         1          0         1
# 4    7420.0         4          1        2         1          1         1
# ..      ...       ...        ...      ...       ...        ...       ...
# 540  3000.0         2          1        1         1          0         1
# 541  2562.0         3          1        1         0          0         0
# 542  3620.0         2          1        1         1          0         0
# 543  2910.0         3          1        1         0          0         0
# 544  3850.0         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %% [markdown]
# # 9. Scale the independent variables

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X_ = sc.fit_transform(X)
X = pd.DataFrame(X_, columns = X.columns)
# Y = sc.fit_transform(np.array(Y).reshape(-1, 1))
Y
# Out:
# 0      8400000.0
# 1      8400000.0
# 2      8400000.0
# 3      8400000.0
# 4      8400000.0
#          ...
# 540    2450000.0
# 541    2450000.0
# 542    2450000.0
# 543    2450000.0
# 544    2450000.0
# Name: price, Length: 545, dtype: float64

# %% [markdown]
# # 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %% [markdown]
# # 11. Build the Model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.feature_selection import RFE
rfe = RFE(lr, 5)
rfe = rfe.fit(X_train, Y_train) # Recursive Feature Elimination
# Out:
# C:\Users\angai\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_features_to_select=5 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['area', 'bathrooms', 'stories', 'basement', 'parking'], dtype='object')

# %%
X_train = X_train[col]
X_train
# Out:
#          area  bathrooms   stories  basement   parking
# 126  0.714197   0.000000  0.000000       1.0  0.666667
# 363  0.158745   0.000000  0.000000       0.0  0.000000
# 370  0.266853   0.000000  0.000000       0.0  0.666667
# 31   0.689345   0.000000  1.000000       0.0  0.666667
# 113  1.000000   0.000000  0.000000       1.0  0.666667
# ..        ...        ...       ...       ...       ...
# 71   0.534017   0.333333  1.000000       0.0  0.000000
# 106  0.448587   0.333333  0.000000       1.0  0.000000
# 270  0.301025   0.333333  0.666667       0.0  0.333333
# 435  0.229574   0.000000  0.000000       0.0  0.000000
# 102  0.456353   0.333333  1.000000       0.0  0.333333
#
# [381 rows x 5 columns]

# %%
X_test = X_test[col]

# %% [markdown]
# # 12. Train the Model

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 13. Test the Model

# %%
Y_pred = lr.predict(X_test)

# %% [markdown]
# # 14. Measure the performance using Metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
rmse = mean_squared_error(Y_test, Y_pred)
mae = mean_absolute_error(Y_test, Y_pred)
rs = r2_score(Y_test, Y_pred)
rs
# Out:
# 0.5096987287147519
